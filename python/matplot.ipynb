# %%
import matplotlib.pyplot as p
import numpy as n
y=n.arange(1,3,0.2)
p.plot(y,'*',y+0.5,'o')
p.grid(True)
p.show()

# %%
import matplotlib.pyplot as p
import numpy as n
y=n.array([3,8,2,10,5,7,6,8])
x=n.array([2,9,0,9,6,7,0,9])
p.plot(y)
p.plot(x)
p.grid()
p.show()

# %%
import matplotlib.pyplot as p
import numpy as n
y=n.array([3,8,1,10,5,7,6,8])
p.plot(y)

p.show()

# %%
import matplotlib.pyplot as p
import numpy as n
x=n.array([1,8])
y=n.array([3,10])
p.plot(x,y,'o')
#p.plot(x,y)
p.show()

# %%
import matplotlib.pyplot as p
import numpy as n
x=n.array([1,8])
y=n.array([3,10])
#p.plot(x,y,'o')
p.plot(x,y)
p.show()

# %%
import matplotlib.pyplot as p
import numpy as n
x=n.array([80,85,90,95,100,105,110,115,120,125])
y=n.array([240,250,260,270,280,290,300,310,320,330])
p.plot(x,y)
p.xlabel("xlabel printed")
p.ylabel("ylabel printed")
p.grid()
p.show()

# %%
import matplotlib.pyplot as p
import numpy as n
x=n.array([80,85,90,95,100,105,110,115,120,125])
y=n.array([240,250,260,270,280,290,300,310,320,330])
p.plot(x,y)
p.xlabel("avg pulse")
p.ylabel("cal burnage")
p.title("sports watch data")
p.grid(color='green',linestyle='--',linewidth=0.5)
##p.grid()
p.show()

# %%
import matplotlib.pyplot as p
import numpy as n
x=n.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=n.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
p.scatter(x,y)
p.show()

# %%
import matplotlib.pyplot as p
import numpy as n
x=n.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=n.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

p.scatter(x,y,color='hotpink')

x=n.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y=n.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
p.scatter(x,y,color='#88c999')

p.show()

# %%
import matplotlib.pyplot as p
import numpy as n
x=n.array(['a','b','c','d'])
y=n.array([3,8,1,10])

p.bar(x,y,color='hotpink')
# Out:
# <BarContainer object of 4 artists>

# %%
import matplotlib.pyplot as p
import numpy as n
x=n.array(['a','b','c','d'])
y=n.array([3,8,1,10])

p.bar(x,y,color='hotpink')
p.barh(x,y,height=0.1)


p.show()

# %%
import matplotlib.pyplot as p
import numpy as n
x=n.random.normal(170,10,250)
p.hist(x)
p.show()

# %%
import matplotlib.pyplot as p
import numpy as n
x=n.array([35,25,25,15])
p.pie(y)
p.show()

# %%
import matplotlib.pyplot as p
import numpy as n
x=n.array([35,25,25,15])
myl={"apple","bananas","cherries","dates"}
p.pie(y,labels=myl)
p.show()
