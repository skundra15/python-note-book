# %%
import pandas as pd
pd.read_csv("C:\\Users\\kundrasu\\Desktop\\python\\Aggregated_Metrics_By_Video.csv")
# Out:
#            Video                                        Video title  \
# 0          Total                                                NaN
# 1    4OZip0cgOho  How I Would Learn Data Science (If I Had to St...
# 2    78LjdAAw0wA                  100K Channel Update + AMA Stream!
# 3    hO_YKK_0Qck  Uber Driver to Machine Learning Engineer in 9 ...
# 4    uXLnbdHMf8w          Why I'm Starting Data Science Over Again.
# ..           ...                                                ...
# 219  FBgs-BSTIJE                    Demystifying Data Science Roles
# 220  Yr5T3T4tq-g  Most Data Science Hopefuls Overlook This Impor...
# 221  j-Z-je6K4Yg                   IT'S NOT TOO LATE TO LEARN CODE!
# 222  5jntoZX-Tc8  NASA Physicist Turned Data Scientist (Tim Bowl...
# 223  5p73cIRYCZg                     ProjectDemoCSC478_UFCFightData
#
#     Video pub­lish time  Com­ments ad­ded  Shares  Dis­likes   Likes  \
# 0                   NaN             14197   39640       3902  225021
# ...

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\kundrasu\\Desktop\\python\\Aggregated_Metrics_By_Video.csv")
print(df)
# Out:
#            Video                                        Video title  \
# 0          Total                                                NaN
# 1    4OZip0cgOho  How I Would Learn Data Science (If I Had to St...
# 2    78LjdAAw0wA                  100K Channel Update + AMA Stream!
# 3    hO_YKK_0Qck  Uber Driver to Machine Learning Engineer in 9 ...
# 4    uXLnbdHMf8w          Why I'm Starting Data Science Over Again.
# ..           ...                                                ...
# 219  FBgs-BSTIJE                    Demystifying Data Science Roles
# 220  Yr5T3T4tq-g  Most Data Science Hopefuls Overlook This Impor...
# 221  j-Z-je6K4Yg                   IT'S NOT TOO LATE TO LEARN CODE!
# 222  5jntoZX-Tc8  NASA Physicist Turned Data Scientist (Tim Bowl...
# 223  5p73cIRYCZg                     ProjectDemoCSC478_UFCFightData
#
#     Video pub­lish time  Com­ments ad­ded  Shares  Dis­likes   Likes  \
# 0                   NaN             14197   39640       3902  225021
# ...

# %%
df.isnull().sum()
# Out:
# Video                                   0
# Video title                             1
# Video pub­lish time                     1
# Com­ments ad­ded                        0
# Shares                                  0
# Dis­likes                               0
# Likes                                   0
# Sub­scribers lost                       0
# Sub­scribers gained                     0
# RPM (USD)                               0
# CPM (USD)                               2
# Av­er­age per­cent­age viewed (%)       0
# Av­er­age view dur­a­tion               0
# Views                                   0
# Watch time (hours)                      0
# Sub­scribers                            0
# Your es­tim­ated rev­en­ue (USD)        0
# Im­pres­sions                           0
# Im­pres­sions click-through rate (%)    0
# dtype: int64

# %%
df1=df.fillna({'Video title':'heloo',
              'Video pub­lish time':'20sep',
              'CPM (USD)':'66'})
print(df1)
# Out:
#            Video                                        Video title  \
# 0          Total                                              heloo
# 1    4OZip0cgOho  How I Would Learn Data Science (If I Had to St...
# 2    78LjdAAw0wA                  100K Channel Update + AMA Stream!
# 3    hO_YKK_0Qck  Uber Driver to Machine Learning Engineer in 9 ...
# 4    uXLnbdHMf8w          Why I'm Starting Data Science Over Again.
# ..           ...                                                ...
# 219  FBgs-BSTIJE                    Demystifying Data Science Roles
# 220  Yr5T3T4tq-g  Most Data Science Hopefuls Overlook This Impor...
# 221  j-Z-je6K4Yg                   IT'S NOT TOO LATE TO LEARN CODE!
# 222  5jntoZX-Tc8  NASA Physicist Turned Data Scientist (Tim Bowl...
# 223  5p73cIRYCZg                     ProjectDemoCSC478_UFCFightData
#
#     Video pub­lish time  Com­ments ad­ded  Shares  Dis­likes   Likes  \
# 0                 20sep             14197   39640       3902  225021
# ...

# %%
df1.isnull().sum()
# Out:
# Video                                   0
# Video title                             0
# Video pub­lish time                     0
# Com­ments ad­ded                        0
# Shares                                  0
# Dis­likes                               0
# Likes                                   0
# Sub­scribers lost                       0
# Sub­scribers gained                     0
# RPM (USD)                               0
# CPM (USD)                               0
# Av­er­age per­cent­age viewed (%)       0
# Av­er­age view dur­a­tion               0
# Views                                   0
# Watch time (hours)                      0
# Sub­scribers                            0
# Your es­tim­ated rev­en­ue (USD)        0
# Im­pres­sions                           0
# Im­pres­sions click-through rate (%)    0
# dtype: int64

# %%
print(df1)
# Out:
#            Video                                        Video title  \
# 0          Total                                              heloo
# 1    4OZip0cgOho  How I Would Learn Data Science (If I Had to St...
# 2    78LjdAAw0wA                  100K Channel Update + AMA Stream!
# 3    hO_YKK_0Qck  Uber Driver to Machine Learning Engineer in 9 ...
# 4    uXLnbdHMf8w          Why I'm Starting Data Science Over Again.
# ..           ...                                                ...
# 219  FBgs-BSTIJE                    Demystifying Data Science Roles
# 220  Yr5T3T4tq-g  Most Data Science Hopefuls Overlook This Impor...
# 221  j-Z-je6K4Yg                   IT'S NOT TOO LATE TO LEARN CODE!
# 222  5jntoZX-Tc8  NASA Physicist Turned Data Scientist (Tim Bowl...
# 223  5p73cIRYCZg                     ProjectDemoCSC478_UFCFightData
#
#     Video pub­lish time  Com­ments ad­ded  Shares  Dis­likes   Likes  \
# 0                 20sep             14197   39640       3902  225021
# ...

# %%
df.dropna()
df
# Out:
#            Video                                        Video title  \
# 0          Total                                                NaN
# 1    4OZip0cgOho  How I Would Learn Data Science (If I Had to St...
# 2    78LjdAAw0wA                  100K Channel Update + AMA Stream!
# 3    hO_YKK_0Qck  Uber Driver to Machine Learning Engineer in 9 ...
# 4    uXLnbdHMf8w          Why I'm Starting Data Science Over Again.
# ..           ...                                                ...
# 219  FBgs-BSTIJE                    Demystifying Data Science Roles
# 220  Yr5T3T4tq-g  Most Data Science Hopefuls Overlook This Impor...
# 221  j-Z-je6K4Yg                   IT'S NOT TOO LATE TO LEARN CODE!
# 222  5jntoZX-Tc8  NASA Physicist Turned Data Scientist (Tim Bowl...
# 223  5p73cIRYCZg                     ProjectDemoCSC478_UFCFightData
#
#     Video pub­lish time  Com­ments ad­ded  Shares  Dis­likes   Likes  \
# 0                   NaN             14197   39640       3902  225021
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#            Video                                        Video title  \
# 1    4OZip0cgOho  How I Would Learn Data Science (If I Had to St...
# 2    78LjdAAw0wA                  100K Channel Update + AMA Stream!
# 3    hO_YKK_0Qck  Uber Driver to Machine Learning Engineer in 9 ...
# 4    uXLnbdHMf8w          Why I'm Starting Data Science Over Again.
# 5    Xgg7dIKys9E  Interview with the Director of AI Research @ N...
# ..           ...                                                ...
# 218  smeFkHwnM_k     Welcome To My Channel | Ken Jee | Data Science
# 219  FBgs-BSTIJE                    Demystifying Data Science Roles
# 220  Yr5T3T4tq-g  Most Data Science Hopefuls Overlook This Impor...
# 221  j-Z-je6K4Yg                   IT'S NOT TOO LATE TO LEARN CODE!
# 222  5jntoZX-Tc8  NASA Physicist Turned Data Scientist (Tim Bowl...
#
#     Video pub­lish time  Com­ments ad­ded  Shares  Dis­likes  Likes  \
# 1           May 8, 2020               907    9583        942  46903
# ...

# %%
df.isnull().sum()
# Out:
# Video                                   0
# Video title                             0
# Video pub­lish time                     0
# Com­ments ad­ded                        0
# Shares                                  0
# Dis­likes                               0
# Likes                                   0
# Sub­scribers lost                       0
# Sub­scribers gained                     0
# RPM (USD)                               0
# CPM (USD)                               0
# Av­er­age per­cent­age viewed (%)       0
# Av­er­age view dur­a­tion               0
# Views                                   0
# Watch time (hours)                      0
# Sub­scribers                            0
# Your es­tim­ated rev­en­ue (USD)        0
# Im­pres­sions                           0
# Im­pres­sions click-through rate (%)    0
# dtype: int64

# %%
df.duplicated()
# Out:
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 218    False
# 219    False
# 220    False
# 221    False
# 222    False
# Length: 221, dtype: bool

# %%
df.duplicated().sum()
print(df)
# Out:
#            Video                                        Video title  \
# 1    4OZip0cgOho  How I Would Learn Data Science (If I Had to St...
# 2    78LjdAAw0wA                  100K Channel Update + AMA Stream!
# 3    hO_YKK_0Qck  Uber Driver to Machine Learning Engineer in 9 ...
# 4    uXLnbdHMf8w          Why I'm Starting Data Science Over Again.
# 5    Xgg7dIKys9E  Interview with the Director of AI Research @ N...
# ..           ...                                                ...
# 218  smeFkHwnM_k     Welcome To My Channel | Ken Jee | Data Science
# 219  FBgs-BSTIJE                    Demystifying Data Science Roles
# 220  Yr5T3T4tq-g  Most Data Science Hopefuls Overlook This Impor...
# 221  j-Z-je6K4Yg                   IT'S NOT TOO LATE TO LEARN CODE!
# 222  5jntoZX-Tc8  NASA Physicist Turned Data Scientist (Tim Bowl...
#
#     Video pub­lish time  Com­ments ad­ded  Shares  Dis­likes  Likes  \
# 1           May 8, 2020               907    9583        942  46903
# ...
