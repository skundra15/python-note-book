# %%
import pandas as pd
pd.read_csv("C:\\Users\\kundrasu\\Desktop\\python\\All_Comments_Final.csv")
# Out:
#                                                 Comments  \
# 0      Thanks for this video Ken.\n\nI decided to go ...
# 1      Hello ken jee!!! I'm doing a graduation on Com...
# 2      Thanks for this video, man. So useful. I'll me...
# 3      Great video!!! I started learning Python 8 mon...
# 4      Been watching hours of your material (and Tina...
# ...                                                  ...
# 10235  Dear Ken,\nMay I know how the input data with ...
# 10236  What's your prediction Ken for 2018 or at leas...
# 10237  Nice. I have some nice models for this doing v...
# 10238  Great video! Can you please post the github li...
# 10239  Hi Ken\n\nI've been researching about this. Wo...
#
#                        Comment_ID  Reply_Count  Like_Count  \
# 0                             NaN          NaN         NaN
# 1      Ugx3IYuAufhb932GYQx4AaABAg          0.0         0.0
# 2      UgyhwwoK24arzRt1mud4AaABAg          0.0         0.0
# ...

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\kundrasu\\Desktop\\python\\All_Comments_Final.csv")
print(df)
# Out:
#                                                 Comments  \
# 0      Thanks for this video Ken.\n\nI decided to go ...
# 1      Hello ken jee!!! I'm doing a graduation on Com...
# 2      Thanks for this video, man. So useful. I'll me...
# 3      Great video!!! I started learning Python 8 mon...
# 4      Been watching hours of your material (and Tina...
# ...                                                  ...
# 10235  Dear Ken,\nMay I know how the input data with ...
# 10236  What's your prediction Ken for 2018 or at leas...
# 10237  Nice. I have some nice models for this doing v...
# 10238  Great video! Can you please post the github li...
# 10239  Hi Ken\n\nI've been researching about this. Wo...
#
#                        Comment_ID  Reply_Count  Like_Count  \
# 0                             NaN          NaN         NaN
# 1      Ugx3IYuAufhb932GYQx4AaABAg          0.0         0.0
# 2      UgyhwwoK24arzRt1mud4AaABAg          0.0         0.0
# ...

# %%
df.isnull().sum()
# Out:
# Comments        1
# Comment_ID      1
# Reply_Count     9
# Like_Count     10
# Date            1
# VidId           0
# user_ID         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Comments', 'Comment_ID', 'Reply_Count', 'Like_Count', 'Date', 'VidId',
#        'user_ID'],
#       dtype='object')

# %%
df1 = df.fillna({
                'Comments':'hey','Comment_ID':'landis','Reply_Count':'5','Like_Count':'69','Date':'26/11/2010'})

# %%
print(df1)
# Out:
#                                                 Comments  \
# 0      Thanks for this video Ken.\n\nI decided to go ...
# 1      Hello ken jee!!! I'm doing a graduation on Com...
# 2      Thanks for this video, man. So useful. I'll me...
# 3      Great video!!! I started learning Python 8 mon...
# 4      Been watching hours of your material (and Tina...
# ...                                                  ...
# 10235  Dear Ken,\nMay I know how the input data with ...
# 10236  What's your prediction Ken for 2018 or at leas...
# 10237  Nice. I have some nice models for this doing v...
# 10238  Great video! Can you please post the github li...
# 10239  Hi Ken\n\nI've been researching about this. Wo...
#
#                        Comment_ID Reply_Count Like_Count  \
# 0                          landis           5         69
# 1      Ugx3IYuAufhb932GYQx4AaABAg         0.0        0.0
# 2      UgyhwwoK24arzRt1mud4AaABAg         0.0        0.0
# ...

# %%
df1.isnull().sum()
# Out:
# Comments       0
# Comment_ID     0
# Reply_Count    0
# Like_Count     0
# Date           0
# VidId          0
# user_ID        0
# dtype: int64

# %%
df1.duplicated().sum()
print(df1)
# Out:
#                                                 Comments  \
# 0      Thanks for this video Ken.\n\nI decided to go ...
# 1      Hello ken jee!!! I'm doing a graduation on Com...
# 2      Thanks for this video, man. So useful. I'll me...
# 3      Great video!!! I started learning Python 8 mon...
# 4      Been watching hours of your material (and Tina...
# ...                                                  ...
# 10235  Dear Ken,\nMay I know how the input data with ...
# 10236  What's your prediction Ken for 2018 or at leas...
# 10237  Nice. I have some nice models for this doing v...
# 10238  Great video! Can you please post the github li...
# 10239  Hi Ken\n\nI've been researching about this. Wo...
#
#                        Comment_ID Reply_Count Like_Count  \
# 0                          landis           5         69
# 1      Ugx3IYuAufhb932GYQx4AaABAg         0.0        0.0
# 2      UgyhwwoK24arzRt1mud4AaABAg         0.0        0.0
# ...

# %%
df.count()
# Out:
# Comments       10239
# Comment_ID     10239
# Reply_Count    10231
# Like_Count     10230
# Date           10239
# VidId          10240
# user_ID        10240
# dtype: int64

# %%
df.head(20)
# Out:
#                                              Comments  \
# 0   Thanks for this video Ken.\n\nI decided to go ...
# 1   Hello ken jee!!! I'm doing a graduation on Com...
# 2   Thanks for this video, man. So useful. I'll me...
# 3   Great video!!! I started learning Python 8 mon...
# 4   Been watching hours of your material (and Tina...
# 5   Hey Ken! I am almost finishing my university d...
# 6   So basically is it modest to say that the silv...
# 7   Hi Ken, as always, your videos are insightful ...
# 8   Watching this for a second time while working ...
# 9                Any good resume templates I can use?
# 10                             Like Bayesian probably
# 11  Hey Ken! Great introductory video! Thanks :) i...
# 12  Hey Ken! I would love to hear opinion from you...
# 13                                    Thank you sir ⚡
# 14  Great! Now I can just shove this video in my p...
# 15  Sir I'm from Bangladesh. I am doing bachelor i...
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10240 entries, 0 to 10239
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Comments     10240 non-null  object
#  1   Comment_ID   10240 non-null  object
#  2   Reply_Count  10240 non-null  object
#  3   Like_Count   10240 non-null  object
#  4   Date         10240 non-null  object
#  5   VidId        10240 non-null  object
#  6   user_ID      10240 non-null  object
# dtypes: object(7)
# memory usage: 560.1+ KB

# %%
df1.head(20)
# Out:
#                                              Comments  \
# 0   Thanks for this video Ken.\n\nI decided to go ...
# 1   Hello ken jee!!! I'm doing a graduation on Com...
# 2   Thanks for this video, man. So useful. I'll me...
# 3   Great video!!! I started learning Python 8 mon...
# 4   Been watching hours of your material (and Tina...
# 5   Hey Ken! I am almost finishing my university d...
# 6   So basically is it modest to say that the silv...
# 7   Hi Ken, as always, your videos are insightful ...
# 8   Watching this for a second time while working ...
# 9                Any good resume templates I can use?
# 10                             Like Bayesian probably
# 11  Hey Ken! Great introductory video! Thanks :) i...
# 12  Hey Ken! I would love to hear opinion from you...
# 13                                    Thank you sir ⚡
# 14  Great! Now I can just shove this video in my p...
# 15  Sir I'm from Bangladesh. I am doing bachelor i...
# ...

# %%
df.tail(9)
# Out:
#                                                 Comments  \
# 10231          Github code? It was promised 4 months ago
# 10232  Any updates on this? Is it still better than 5...
# 10233                             There is no github ...
# 10234  What do you think about NARX? Any experience w...
# 10235  Dear Ken,\nMay I know how the input data with ...
# 10236  What's your prediction Ken for 2018 or at leas...
# 10237  Nice. I have some nice models for this doing v...
# 10238  Great video! Can you please post the github li...
# 10239  Hi Ken\n\nI've been researching about this. Wo...
#
#                        Comment_ID  Reply_Count  Like_Count  \
# 10231  Ugy_z-_l_ZtcQITDlPN4AaABAg          1.0        12.0
# 10232  UgxMk5AJyQ0SAqie8b14AaABAg          0.0         1.0
# 10233  Ugxd1-4ZfFzS3ZliJdl4AaABAg          0.0         1.0
# 10234  UgxDFoXxF5FMDMzA4-54AaABAg          0.0         0.0
# 10235  UgzX5v48CJAPbvynwTR4AaABAg          1.0         0.0
# ...

# %%
df1.tail(69)
# Out:
#                                                 Comments  \
# 10171  Hey Ken, \nCould you elaborate more on last 3 ...
# 10172                         Comment first, then watch!
# 10173  u jost got urself a fellow data science studen...
# 10174  Hey PSA (maybe pin this or comment this yourse...
# 10175  Can you make a vid of your resume so that we c...
# ...                                                  ...
# 10235  Dear Ken,\nMay I know how the input data with ...
# 10236  What's your prediction Ken for 2018 or at leas...
# 10237  Nice. I have some nice models for this doing v...
# 10238  Great video! Can you please post the github li...
# 10239  Hi Ken\n\nI've been researching about this. Wo...
#
#                        Comment_ID Reply_Count Like_Count  \
# 10171  UgwO61C5-mzyzvCFl2B4AaABAg         1.0        6.0
# 10172  Ugzzzuo0L_ilJ1Ue1f14AaABAg         0.0        6.0
# 10173  UgyxUnqItRa-4LZg9Fd4AaABAg         0.0        9.0
# ...

# %%
pd.read_csv('C:\\Users\\kundrasu\\Desktop\\python\\All_Comments_Final.csv',header=0,usecols=["Comment_ID","Reply_Count"])
# Out:
#                        Comment_ID  Reply_Count
# 0                             NaN          NaN
# 1      Ugx3IYuAufhb932GYQx4AaABAg          0.0
# 2      UgyhwwoK24arzRt1mud4AaABAg          0.0
# 3      UgwrrI7nd3WClsotmHV4AaABAg          0.0
# 4      UgxlOrHO4MHKSwY9mUN4AaABAg          0.0
# ...                           ...          ...
# 10235  UgzX5v48CJAPbvynwTR4AaABAg          1.0
# 10236  UgwdI9ydb2nk-FIJ1sN4AaABAg          0.0
# 10237  UgyTi5fEIpZBoED9Fc94AaABAg          0.0
# 10238  UgyhJTCKn88b0lggR794AaABAg          0.0
# 10239  UgzG1dz-KieX_gxjMWd4AaABAg          6.0
#
# [10240 rows x 2 columns]

# %%
df1=df.fillna({'Date':'2022-01-22T08:13:29Z'})
(df1)
# Out:
#                                                 Comments  \
# 0      Thanks for this video Ken.\n\nI decided to go ...
# 1      Hello ken jee!!! I'm doing a graduation on Com...
# 2      Thanks for this video, man. So useful. I'll me...
# 3      Great video!!! I started learning Python 8 mon...
# 4      Been watching hours of your material (and Tina...
# ...                                                  ...
# 10235  Dear Ken,\nMay I know how the input data with ...
# 10236  What's your prediction Ken for 2018 or at leas...
# 10237  Nice. I have some nice models for this doing v...
# 10238  Great video! Can you please post the github li...
# 10239  Hi Ken\n\nI've been researching about this. Wo...
#
#                        Comment_ID  Reply_Count  Like_Count  \
# 0                             NaN          NaN         NaN
# 1      Ugx3IYuAufhb932GYQx4AaABAg          0.0         0.0
# 2      UgyhwwoK24arzRt1mud4AaABAg          0.0         0.0
# ...
